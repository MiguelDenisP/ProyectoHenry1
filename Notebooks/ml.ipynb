# %% [markdown]
# ## Preparación Datos para el Modelo de Recomendacion

# %% [markdown]
# ## Preparación Datos para el Modelo de Recomendacion

# %% [markdown]
# Para evitar problemas con la capacidad de memoria en el deployment en Render, se trabaja previamente este dataset para prepararlo para el modelo

# %%
import pandas as pd
import numpy as np
from nltk import word_tokenize
from scipy.sparse import hstack
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\migue\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\migue\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("../Data/limpio2.csv")

# %%
df.head(3)
# Out:
#       id                                           overview  popularity  \
# 0    862  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1   8844  When siblings Judy and Peter discover an encha...   17.015539
# 2  15602  A family wedding reignites the ancient feud be...   11.712900
#
#               title  vote_average                        genres_names  \
# 0         Toy Story           7.7   ['Animation', 'Comedy', 'Family']
# 1           Jumanji           6.9  ['Adventure', 'Fantasy', 'Family']
# 2  Grumpier Old Men           6.5               ['Romance', 'Comedy']
#
#                           production_companies_names production_countries_iso  \
# 0                        ['Pixar Animation Studios']                   ['US']
# 1  ['TriStar Pictures', 'Teitler Film', 'Intersco...                   ['US']
# 2                 ['Warner Bros.', 'Lancaster Gate']                   ['US']
#
#   spoken_languages_iso  belongs_to_collection_id  \
# 0               ['en']                   10194.0
# 1         ['en', 'fr']                       NaN
# 2               ['en']                  119050.0
#
#                                           cast_names  director_name
# 0  ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim...  John Lasseter
# 1  ['Robin Williams', 'Jonathan Hyde', 'Kirsten D...   Joe Johnston
# 2  ['Walter Matthau', 'Jack Lemmon', 'Ann-Margret...  Howard Deutch

# %%
columnas_ml = ['overview', 'title', 'director_name','genres_names', 'production_companies_names']
df = df[columnas_ml]
df
# Out:
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 43267  Yet another version of the classic epic, with ...
# 43268  An artist struggles to finish his work while a...
# 43269  When one of her hits goes wrong, a professiona...
# 43270  In a small town live two brothers, one a minis...
# 43271  50 years after decriminalisation of homosexual...
#
#                              title     director_name  \
# 0                        Toy Story     John Lasseter
# 1                          Jumanji      Joe Johnston
# 2                 Grumpier Old Men     Howard Deutch
# 3                Waiting to Exhale   Forest Whitaker
# 4      Father of the Bride Part II     Charles Shyer
# ...                            ...               ...
# 43267                   Robin Hood        John Irvin
# 43268          Century of Birthing          Lav Diaz
# 43269                     Betrayal    Mark L. Lester
# 43270             Satan Triumphant  Yakov Protazanov
# 43271                     Queerama     Daisy Asquith
#
#                              genres_names  \
# 0       ['Animation', 'Comedy', 'Family']
# 1      ['Adventure', 'Fantasy', 'Family']
# 2                   ['Romance', 'Comedy']
# 3          ['Comedy', 'Drama', 'Romance']
# 4                              ['Comedy']
# ...                                   ...
# 43267      ['Drama', 'Action', 'Romance']
# 43268                           ['Drama']
# 43269     ['Action', 'Drama', 'Thriller']
# 43270                                  []
# 43271                                  []
#
#                               production_companies_names
# 0                            ['Pixar Animation Studios']
# 1      ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 2                     ['Warner Bros.', 'Lancaster Gate']
# 3             ['Twentieth Century Fox Film Corporation']
# 4       ['Sandollar Productions', 'Touchstone Pictures']
# ...                                                  ...
# 43267  ['Westdeutscher Rundfunk (WDR)', 'Working Titl...
# 43268                                    ['Sine Olivia']
# 43269                        ['American World Pictures']
# 43270                                      ['Yermoliev']
# 43271                                                 []
#
# [43272 rows x 5 columns]

# %%
# se descargan librerias de palabras stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\migue\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\migue\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# se genera un conjunto de las stopwords en inglés
stop_words = set(stopwords.words('english'))

# funciona para tokenizar texto
def preprocess(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    words =word_tokenize(text)
    words = [word for word in words if word.isalnum() and word not in stop_words]
    return ' '.join(words)

# %%
# se aplica la tokenizacion a las columnas escogidas
for column in columnas_ml:
    df[f'tokenizada_{column}'] = df[column].apply(preprocess)

# %%
# se eliminan columnas originales
columnas_tokenizadas = ['title','tokenizada_overview', 'tokenizada_title', 'tokenizada_director_name', 'tokenizada_genres_names', 'tokenizada_production_companies_names']
df = df[columnas_tokenizadas]
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 43267                   Robin Hood
# 43268          Century of Birthing
# 43269                     Betrayal
# 43270             Satan Triumphant
# 43271                     Queerama
#
#                                      tokenizada_overview  \
# 0      led woody andy toys live happily room andy bir...
# 1      siblings judy peter discover enchanted board g...
# 2      family wedding reignites ancient feud neighbor...
# 3      cheated mistreated stepped women holding breat...
# 4      george banks recovered daughter wedding receiv...
# ...                                                  ...
# 43267  yet another version classic epic enough variat...
# 43268  artist struggles finish work storyline cult pl...
# 43269  one hits goes wrong professional assassin ends...
# 43270  small town live two brothers one minister one ...
# 43271  50 years decriminalisation homosexuality uk di...
#
#            tokenizada_title tokenizada_director_name tokenizada_genres_names  \
# 0                 toy story            john lasseter
# 1                   jumanji             joe johnston
# 2          grumpier old men            howard deutch
# 3            waiting exhale          forest whitaker
# 4      father bride part ii            charles shyer
# ...                     ...                      ...                     ...
# 43267            robin hood               john irvin
# 43268      century birthing                 lav diaz
# 43269              betrayal              mark lester
# 43270      satan triumphant         yakov protazanov
# 43271              queerama            daisy asquith
#
#                    tokenizada_production_companies_names
# 0                                      animation studios
# 1                           pictures film communications
# 2                                                   gate
# 3                           century fox film corporation
# 4                                   productions pictures
# ...                                                  ...
# 43267  rundfunk wdr title films century fox televisio...
# 43268                                             olivia
# 43269                                     world pictures
# 43270
# 43271
#
# [43272 rows x 6 columns]

# %%
# Botamos genre hasta que funcione
df = df.drop(columns=['tokenizada_genres_names'])
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 43267                   Robin Hood
# 43268          Century of Birthing
# 43269                     Betrayal
# 43270             Satan Triumphant
# 43271                     Queerama
#
#                                      tokenizada_overview  \
# 0      led woody andy toys live happily room andy bir...
# 1      siblings judy peter discover enchanted board g...
# 2      family wedding reignites ancient feud neighbor...
# 3      cheated mistreated stepped women holding breat...
# 4      george banks recovered daughter wedding receiv...
# ...                                                  ...
# 43267  yet another version classic epic enough variat...
# 43268  artist struggles finish work storyline cult pl...
# 43269  one hits goes wrong professional assassin ends...
# 43270  small town live two brothers one minister one ...
# 43271  50 years decriminalisation homosexuality uk di...
#
#            tokenizada_title tokenizada_director_name  \
# 0                 toy story            john lasseter
# 1                   jumanji             joe johnston
# 2          grumpier old men            howard deutch
# 3            waiting exhale          forest whitaker
# 4      father bride part ii            charles shyer
# ...                     ...                      ...
# 43267            robin hood               john irvin
# 43268      century birthing                 lav diaz
# 43269              betrayal              mark lester
# 43270      satan triumphant         yakov protazanov
# 43271              queerama            daisy asquith
#
#                    tokenizada_production_companies_names
# 0                                      animation studios
# 1                           pictures film communications
# 2                                                   gate
# 3                           century fox film corporation
# 4                                   productions pictures
# ...                                                  ...
# 43267  rundfunk wdr title films century fox televisio...
# 43268                                             olivia
# 43269                                     world pictures
# 43270
# 43271
#
# [43272 rows x 5 columns]

# %% [markdown]
# ### en este

# %%
# se guarda el dataset tokenizado para entrenar el modelo
# df.to_csv('data_modelo.csv', index=False)
